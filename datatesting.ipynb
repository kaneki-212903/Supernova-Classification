# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('astrotrain.xlsx')

# %%
data.head()
# Out:
#                                   SUBSURVEY      SNID              IAUC  FAKE  \
# 0                                            10473255  NULL                 2
# 1                                             2110040  NULL                 2
# 2                                             9966178  NULL                 2
# 3                                            19732134  NULL                 2
# 4                                             1582526  NULL                 2
#
#           RA       DECL  PIXSIZE  NXPIX  NYPIX  CCDNUM  ...  SIM_PEAKMAG_z  \
# 0  53.468451 -28.349424     0.27     -9     -9      44  ...      23.664705
# 1  53.508185 -28.470810     0.27     -9     -9      50  ...      24.363064
# 2  35.077432  -6.979272     0.27     -9     -9      51  ...      23.319248
# 3  52.852204 -27.184372     0.27     -9     -9       3  ...      22.917084
# 4  36.932302  -5.248342     0.27     -9     -9      55  ...      22.626780
#
# ...

# %%
#dropping attributes with indexes 0,1,2

data.drop(data.columns[[0,1,2]], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['FAKE', 'RA', 'DECL', 'PIXSIZE', 'NXPIX', 'NYPIX', 'CCDNUM', 'SNTYPE',
#        'NOBS', 'PTROBS_MIN', 'PTROBS_MAX', 'MWEBV', 'MWEBV_ERR',
#        'REDSHIFT_HELIO', 'REDSHIFT_HELIO_ERR', 'REDSHIFT_FINAL',
#        'REDSHIFT_FINAL_ERR', 'VPEC', 'VPEC_ERR', 'HOSTGAL_OBJID',
#        'HOSTGAL_PHOTOZ', 'HOSTGAL_PHOTOZ_ERR', 'HOSTGAL_SPECZ',
#        'HOSTGAL_SPECZ_ERR', 'HOSTGAL_SNSEP', 'HOSTGAL_LOGMASS',
#        'HOSTGAL_LOGMASS_ERR', 'HOSTGAL_MAG_g', 'HOSTGAL_MAG_r',
#        'HOSTGAL_MAG_i', 'HOSTGAL_MAG_z', 'HOSTGAL_SB_FLUXCAL_g',
#        'HOSTGAL_SB_FLUXCAL_r', 'HOSTGAL_SB_FLUXCAL_i', 'HOSTGAL_SB_FLUXCAL_z',
#        'PEAKMJD', 'SEARCH_TYPE', 'SIM_MODEL_NAME', 'SIM_MODEL_INDEX',
#        'SIM_TYPE_INDEX', 'SIM_TYPE_NAME', 'SIM_NON1a', 'SIM_LIBID',
#        'SIM_NGEN_LIBID', 'SIM_NOBS_UNDEFINED', 'SIM_SEARCHEFF_MASK',
#        'SIM_REDSHIFT_HELIO', 'SIM_REDSHIFT_CMB', 'SIM_REDSHIFT_HOST',
#        'SIM_VPEC', 'SIM_HOSTLIB(Mi_abs)', 'SIM_DLMU', 'SIM_LENSDMU', 'SIM_RA',
# ...

# %%
#checking index of column

print(data.columns.get_loc("CCDNUM"))
print(data.columns.get_loc("HOSTGAL_OBJID"))
print(data.columns.get_loc("SIM_MODEL_NAME"))
print(data.columns.get_loc("SIM_MODEL_INDEX"))
print(data.columns.get_loc("SIM_TYPE_INDEX"))
print(data.columns.get_loc("SIM_TYPE_NAME"))
print(data.columns.get_loc("SIM_LIBID"))
print(data.columns.get_loc("SIM_NGEN_LIBID"))
print(data.columns.get_loc("SIM_SEARCHEFF_MASK"))
print(data.columns.get_loc("SIM_NOBS_UNDEFINED"))
# Out:
# 6
# 19
# 37
# 38
# 39
# 40
# 42
# 43
# 45
# 44

# %%
data.drop(data.columns[[6,19,37,38,39,40,42,43,45,44]], axis=1, inplace=True)

# %%
data.shape
# Out:
# (40000, 69)

# %%
data.columns
# Out:
# Index(['FAKE', 'RA', 'DECL', 'PIXSIZE', 'NXPIX', 'NYPIX', 'SNTYPE', 'NOBS',
#        'PTROBS_MIN', 'PTROBS_MAX', 'MWEBV', 'MWEBV_ERR', 'REDSHIFT_HELIO',
#        'REDSHIFT_HELIO_ERR', 'REDSHIFT_FINAL', 'REDSHIFT_FINAL_ERR', 'VPEC',
#        'VPEC_ERR', 'HOSTGAL_PHOTOZ', 'HOSTGAL_PHOTOZ_ERR', 'HOSTGAL_SPECZ',
#        'HOSTGAL_SPECZ_ERR', 'HOSTGAL_SNSEP', 'HOSTGAL_LOGMASS',
#        'HOSTGAL_LOGMASS_ERR', 'HOSTGAL_MAG_g', 'HOSTGAL_MAG_r',
#        'HOSTGAL_MAG_i', 'HOSTGAL_MAG_z', 'HOSTGAL_SB_FLUXCAL_g',
#        'HOSTGAL_SB_FLUXCAL_r', 'HOSTGAL_SB_FLUXCAL_i', 'HOSTGAL_SB_FLUXCAL_z',
#        'PEAKMJD', 'SEARCH_TYPE', 'SIM_NON1a', 'SIM_REDSHIFT_HELIO',
#        'SIM_REDSHIFT_CMB', 'SIM_REDSHIFT_HOST', 'SIM_VPEC',
#        'SIM_HOSTLIB(Mi_abs)', 'SIM_DLMU', 'SIM_LENSDMU', 'SIM_RA', 'SIM_DECL',
#        'SIM_MWEBV', 'SIM_PEAKMJD', 'SIM_MAGSMEAR_COH', 'SIM_AV', 'SIM_RV',
#        'SIM_SALT2x0', 'SIM_SALT2x1', 'SIM_SALT2c', 'SIM_SALT2mB',
# ...

# %%
#getting index name from index number

print(data.columns[68])
# Out:
# SIM_SUBSAMPLE_INDEX

# %%
l=[0,3,4,5,16,17,23,24,34,39,42,48,48,49,60,61,62,63,68]
data.drop(data.columns[l], axis=1, inplace=True)

# %%
#Plotting the heatmap of the correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt
corr = data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr, annot=False, cmap='coolwarm',linewidths=0.5)
plt.show()

# %%
#Printing the corrrlation matrix
print(corr)
# Out:
#                             RA      DECL    SNTYPE      NOBS  PTROBS_MIN  \
# RA                    1.000000  0.210762  0.024144 -0.024100    0.002529
# DECL                  0.210762  1.000000 -0.002786 -0.184956    0.008718
# SNTYPE                0.024144 -0.002786  1.000000 -0.029387    0.353170
# NOBS                 -0.024100 -0.184956 -0.029387  1.000000   -0.031798
# PTROBS_MIN            0.002529  0.008718  0.353170 -0.031798    1.000000
# PTROBS_MAX            0.002527  0.008707  0.353169 -0.031741    1.000000
# MWEBV                 0.009156  0.789066 -0.017503 -0.119584    0.005801
# MWEBV_ERR             0.009156  0.789066 -0.017503 -0.119584    0.005801
# REDSHIFT_HELIO        0.126684 -0.001586 -0.420600 -0.026973   -0.118750
# REDSHIFT_HELIO_ERR    0.101656  0.007043 -0.170114 -0.019977   -0.046130
# REDSHIFT_FINAL        0.127548 -0.002278 -0.420522 -0.026811   -0.118740
# REDSHIFT_FINAL_ERR    0.101656  0.007043 -0.170114 -0.019977   -0.046130
# ...

# %%
column_names = data.columns

# %%
#Calculating the interquartile range
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
for i in column_names:
    print(i)
    print(IQR[i])
# Out:
# RA
# 17.150546
# DECL
# 24.006816
# SNTYPE
# 21.0
# NOBS
# 31.0
# PTROBS_MIN
# 717880.25
# PTROBS_MAX
# 717859.5
# MWEBV
# 0.01828911875
# MWEBV_ERR
# 0.0030481867749999995
# REDSHIFT_HELIO
# 0.36114732000000005
# REDSHIFT_HELIO_ERR
# 0.035089999999999996
# REDSHIFT_FINAL
# 0.36114596250000003
# REDSHIFT_FINAL_ERR
# 0.035089999999999996
# HOSTGAL_PHOTOZ
# 0.35843239500000007
# HOSTGAL_PHOTOZ_ERR
# 0.030879999999999998
# HOSTGAL_SPECZ
# 9.5356103
# HOSTGAL_SPECZ_ERR
# 9.0005
# HOSTGAL_SNSEP
# 0.6547391300000001
# HOSTGAL_MAG_g
# 1.704993499999997
# HOSTGAL_MAG_r
# 1.9483334999999968
# HOSTGAL_MAG_i
# 1.9063450000000017
# HOSTGAL_MAG_z
# 1.9793279999999989
# HOSTGAL_SB_FLUXCAL_g
# 12.603591075
# HOSTGAL_SB_FLUXCAL_r
# 37.3257125
# HOSTGAL_SB_FLUXCAL_i
# 59.76540199999999
# HOSTGAL_SB_FLUXCAL_z
# 82.49907350000001
# PEAKMJD
# 643.4289999999964
# SIM_NON1a
# 211.0
# SIM_REDSHIFT_HELIO
# 0.35687180500000004
# SIM_REDSHIFT_CMB
# 0.3567225050000001
# SIM_REDSHIFT_HOST
# 0.352
# ...

# %%
#Calculating skewness
for i in column_names:
    print(i)
    print(data[i].skew())
# Out:
# RA
# -1.0389551240537536
# DECL
# -0.14213577593154647
# SNTYPE
# 0.1476580810467459
# NOBS
# 1.1068149708201924
# PTROBS_MIN
# 0.04342515590124099
# PTROBS_MAX
# 0.04342389252555774
# MWEBV
# 1.8722226723848558
# MWEBV_ERR
# 1.872222660738211
# REDSHIFT_HELIO
# 0.32671659174608564
# REDSHIFT_HELIO_ERR
# 1.3710721873857918
# REDSHIFT_FINAL
# 0.32685624284927106
# REDSHIFT_FINAL_ERR
# 1.3710721873857918
# HOSTGAL_PHOTOZ
# 0.3788940288326213
# HOSTGAL_PHOTOZ_ERR
# 0.7721623068451692
# HOSTGAL_SPECZ
# -0.5953068945755331
# HOSTGAL_SPECZ_ERR
# -0.5994583613186532
# HOSTGAL_SNSEP
# 11.286757356677533
# HOSTGAL_MAG_g
# 5.59312135735361
# HOSTGAL_MAG_r
# 4.95983835739412
# HOSTGAL_MAG_i
# -0.70123621065813
# HOSTGAL_MAG_z
# -0.6460506776984449
# HOSTGAL_SB_FLUXCAL_g
# 7.4070748924898755
# HOSTGAL_SB_FLUXCAL_r
# 5.788110131380018
# HOSTGAL_SB_FLUXCAL_i
# 5.305313161218121
# HOSTGAL_SB_FLUXCAL_z
# 5.361266039107766
# PEAKMJD
# -0.00899856154207608
# SIM_NON1a
# 0.6671994701274852
# ...

# %%
column_names
# Out:
# Index(['RA', 'DECL', 'SNTYPE', 'NOBS', 'PTROBS_MIN', 'PTROBS_MAX', 'MWEBV',
#        'MWEBV_ERR', 'REDSHIFT_HELIO', 'REDSHIFT_HELIO_ERR', 'REDSHIFT_FINAL',
#        'REDSHIFT_FINAL_ERR', 'HOSTGAL_PHOTOZ', 'HOSTGAL_PHOTOZ_ERR',
#        'HOSTGAL_SPECZ', 'HOSTGAL_SPECZ_ERR', 'HOSTGAL_SNSEP', 'HOSTGAL_MAG_g',
#        'HOSTGAL_MAG_r', 'HOSTGAL_MAG_i', 'HOSTGAL_MAG_z',
#        'HOSTGAL_SB_FLUXCAL_g', 'HOSTGAL_SB_FLUXCAL_r', 'HOSTGAL_SB_FLUXCAL_i',
#        'HOSTGAL_SB_FLUXCAL_z', 'PEAKMJD', 'SIM_NON1a', 'SIM_REDSHIFT_HELIO',
#        'SIM_REDSHIFT_CMB', 'SIM_REDSHIFT_HOST', 'SIM_HOSTLIB(Mi_abs)',
#        'SIM_DLMU', 'SIM_RA', 'SIM_DECL', 'SIM_MWEBV', 'SIM_PEAKMJD',
#        'SIM_MAGSMEAR_COH', 'SIM_SALT2x0', 'SIM_SALT2x1', 'SIM_SALT2c',
#        'SIM_SALT2mB', 'SIM_SALT2alpha', 'SIM_SALT2beta', 'SIM_PEAKMAG_g',
#        'SIM_PEAKMAG_r', 'SIM_PEAKMAG_i', 'SIM_PEAKMAG_z', 'SIM_GALFRAC_g',
#        'SIM_GALFRAC_r', 'SIM_GALFRAC_i', 'SIM_GALFRAC_z'],
#       dtype='object')

# %%
data['Total Flux']=(data['HOSTGAL_SB_FLUXCAL_g']**2+data['HOSTGAL_SB_FLUXCAL_r']**2+data['HOSTGAL_SB_FLUXCAL_i']**2+data['HOSTGAL_SB_FLUXCAL_z']**2)/4

# %%
data.head()
# Out:
#           RA       DECL  SNTYPE  NOBS  PTROBS_MIN  PTROBS_MAX     MWEBV  \
# 0  53.468451 -28.349424     133    61     1418390     1418450  0.009902
# 1  53.508185 -28.470810     101    69      713393      713461  0.006961
# 2  35.077432  -6.979272     122    65      802497      802561  0.024851
# 3  52.852204 -27.184372     120    34      111780      111813  0.008636
# 4  36.932302  -5.248342     101    65      230732      230796  0.025626
#
#    MWEBV_ERR  REDSHIFT_HELIO  REDSHIFT_HELIO_ERR  ...  SIM_SALT2beta  \
# 0   0.001650        0.297897             0.05310  ...            NaN
# 1   0.001160        1.101739             0.03574  ...            3.1
# 2   0.004142        0.497172             0.00050  ...            NaN
# 3   0.001439        0.141762             0.00050  ...            NaN
# 4   0.004271        0.468283             0.00050  ...            3.1
#
#    SIM_PEAKMAG_g  SIM_PEAKMAG_r  SIM_PEAKMAG_i  SIM_PEAKMAG_z  SIM_GALFRAC_g  \
# ...

# %%
#Calculating distance in light year using redshift

def distance(redshift):
    speed_of_light=299792458
    Hubble_constant=70
    megaparsec_to_light_year=3.262*10**6

    distance_mega_parsec= (speed_of_light*redshift)/Hubble_constant
    distance_light_year=distance_mega_parsec*megaparsec_to_light_year
    
    return distance_light_year

# %%
#Calculating coordinates x,y,z using redshift and distance and make a new column
import math
def calculate_cartesian_coordinates(ra, decl, distance_light_years):
    
    # Convert angles from degrees to radians
    ra_rad = math.radians(ra)
    decl_rad = math.radians(decl)

    # Calculate Cartesian coordinates
    x = distance_light_years * math.cos(ra_rad) * math.cos(decl_rad)
    y = distance_light_years * math.sin(ra_rad) * math.cos(decl_rad)
    z = distance_light_years * math.sin(decl_rad)

    return x, y, z

# %%
#Calculating coordinates using ra and decl and make a new column
data['x_coordinate']=distance(data['REDSHIFT_FINAL'])*np.cos(np.radians(data['RA']))*np.cos(np.radians(data['DECL']))
data['y_coordinate']=distance(data['REDSHIFT_FINAL'])*np.sin(np.radians(data['RA']))*np.cos(np.radians(data['DECL']))
data['z_coordinate']=distance(data['REDSHIFT_FINAL'])*np.sin(np.radians(data['DECL']))

data.head()
# Out:
#           RA       DECL  SNTYPE  NOBS  PTROBS_MIN  PTROBS_MAX     MWEBV  \
# 0  53.468451 -28.349424     133    61     1418390     1418450  0.009902
# 1  53.508185 -28.470810     101    69      713393      713461  0.006961
# 2  35.077432  -6.979272     122    65      802497      802561  0.024851
# 3  52.852204 -27.184372     120    34      111780      111813  0.008636
# 4  36.932302  -5.248342     101    65      230732      230796  0.025626
#
#    MWEBV_ERR  REDSHIFT_HELIO  REDSHIFT_HELIO_ERR  ...  SIM_PEAKMAG_i  \
# 0   0.001650        0.297897             0.05310  ...      23.709719
# 1   0.001160        1.101739             0.03574  ...      24.971678
# 2   0.004142        0.497172             0.00050  ...      23.518854
# 3   0.001439        0.141762             0.00050  ...      22.609093
# 4   0.004271        0.468283             0.00050  ...      22.506872
#
#    SIM_PEAKMAG_z  SIM_GALFRAC_g  SIM_GALFRAC_r  SIM_GALFRAC_i  SIM_GALFRAC_z  \
# ...

# %%
missing_percentage = (data.isnull().sum() / len(data))* 100

# Create a DataFrame with missing percentage information
missing_info = pd.DataFrame({'Feature':data.columns, 'MissingPercentage': missing_percentage})

# Sort the DataFrame by missing percentage in descending order
missing_info = missing_info.sort_values(by='MissingPercentage', ascending=False)

# Print the missing percentage information
print(missing_info)

# Plot the missing percentage using a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='MissingPercentage', y='Feature', data=missing_info, palette='viridis')
plt.title('Percentage of Missing Values for Each Feature')
plt.xlabel('Missing Percentage')
plt.ylabel('Feature')
plt.show()
# Out:
#                                    Feature  MissingPercentage
# SIM_SALT2beta                SIM_SALT2beta            54.3725
# SIM_SALT2alpha              SIM_SALT2alpha            54.3725
# SIM_SALT2x0                    SIM_SALT2x0            54.3725
# SIM_SALT2x1                    SIM_SALT2x1            54.3725
# SIM_SALT2c                      SIM_SALT2c            54.3725
# SIM_SALT2mB                    SIM_SALT2mB            54.3725
# SIM_HOSTLIB(Mi_abs)    SIM_HOSTLIB(Mi_abs)             0.0000
# SIM_DLMU                          SIM_DLMU             0.0000
# SIM_RA                              SIM_RA             0.0000
# SIM_DECL                          SIM_DECL             0.0000
# SIM_MWEBV                        SIM_MWEBV             0.0000
# SIM_PEAKMJD                    SIM_PEAKMJD             0.0000
# SIM_MAGSMEAR_COH          SIM_MAGSMEAR_COH             0.0000
# RA                                      RA             0.0000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   RA                    40000 non-null  float64
#  1   DECL                  40000 non-null  float64
#  2   SNTYPE                40000 non-null  int64
#  3   NOBS                  40000 non-null  int64
#  4   PTROBS_MIN            40000 non-null  int64
#  5   PTROBS_MAX            40000 non-null  int64
#  6   MWEBV                 40000 non-null  float64
#  7   MWEBV_ERR             40000 non-null  float64
#  8   REDSHIFT_HELIO        40000 non-null  float64
#  9   REDSHIFT_HELIO_ERR    40000 non-null  float64
#  10  REDSHIFT_FINAL        40000 non-null  float64
#  11  REDSHIFT_FINAL_ERR    40000 non-null  float64
#  12  HOSTGAL_PHOTOZ        40000 non-null  float64
#  13  HOSTGAL_PHOTOZ_ERR    40000 non-null  float64
# ...

# %% [markdown]
# We will not consider the columns which contain null values.

# %%
data_dropped = data.drop(['SIM_SALT2x0', 'SIM_SALT2x1', 'SIM_SALT2c', 'SIM_SALT2mB', 'SIM_SALT2alpha', 'SIM_SALT2beta'], axis=1)
data_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   RA                    40000 non-null  float64
#  1   DECL                  40000 non-null  float64
#  2   SNTYPE                40000 non-null  int64
#  3   NOBS                  40000 non-null  int64
#  4   PTROBS_MIN            40000 non-null  int64
#  5   PTROBS_MAX            40000 non-null  int64
#  6   MWEBV                 40000 non-null  float64
#  7   MWEBV_ERR             40000 non-null  float64
#  8   REDSHIFT_HELIO        40000 non-null  float64
#  9   REDSHIFT_HELIO_ERR    40000 non-null  float64
#  10  REDSHIFT_FINAL        40000 non-null  float64
#  11  REDSHIFT_FINAL_ERR    40000 non-null  float64
#  12  HOSTGAL_PHOTOZ        40000 non-null  float64
#  13  HOSTGAL_PHOTOZ_ERR    40000 non-null  float64
# ...

# %%
data_dropped['SNTYPE'].unique()
# Out:
# array([133, 101, 122, 120, 121, 132, 123], dtype=int64)

# %%
X = np.array(data_dropped.drop('SNTYPE', axis=1))
y = np.array(data_dropped['SNTYPE'])
print(f"X.shape = {X.shape}")
print(f"y.shape = {y.shape}")
# Out:
# X.shape = (40000, 48)
# y.shape = (40000,)

# %% [markdown]
# Trying different scalers

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

standardScaler = StandardScaler()
minMaxScaler = MinMaxScaler()

X_standard = standardScaler.fit_transform(X)
X_minmax = minMaxScaler.fit_transform(X)

# %% [markdown]
# Using PCA to reduce the numbers of features in order to plot it

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=1)

X_standard_pca = pca.fit_transform(X_standard)
X_minmax_pca = pca.fit_transform(X_minmax)

# %%
X_standard_pca.shape, X_minmax_pca.shape
# Out:
# ((40000, 1), (40000, 1))

# %%
# Plot the PCA results
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(X_standard_pca, y, c=y, cmap='viridis', alpha=0.5)
plt.title('PCA with Standard Scaler')
plt.xlabel('Principal Component 1')
plt.ylabel('SNTYPE')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.scatter(X_minmax_pca, y, c=y, cmap='viridis', alpha=0.5)
plt.title('PCA with MinMax Scaler')
plt.xlabel('Principal Component 1')
plt.ylabel('SNTYPE')
plt.colorbar()

plt.show()

# %% [markdown]
# We can see that the plot is divided into seven different groups presiding on each line.

# %% [markdown]
# Since the MinMaxScaler's output lines are longer, we will choose that as our feature reducing algorithm since it will retain more information as compared to the StandardScaler.

# %%
pca_10 = PCA(n_components=10)
X_minmax_pca_10 = pca_10.fit_transform(X_minmax)
X_minmax_pca_10.shape
# Out:
# (40000, 10)

# %%
from sklearn.model_selection import train_test_split

X_train, X_, y_train, y_ = train_test_split(X_minmax_pca_10, y, test_size=0.3, random_state=42)
X_cv, X_test, y_cv, y_test = train_test_split(X_, y_, test_size=0.5, random_state=42)

# %% [markdown]
# ## Model Training

# %% [markdown]
# Now, we will try and experiment with different models

# %%
models = ['SGDClassifier', 'RandomForestClassifier', 'KNeighborsClassifier', 'SVC', 'DecisionTreeClassifier', 'LogisticRegression', 'GradientBoostingClassifier', 'XGBClassifier']

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import cross_val_score

logisticRegression = LogisticRegression(max_iter=1000)
logisticRegression.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Get all the metrics
y_train_pred = logisticRegression.predict(X_train)
y_cv_pred = logisticRegression.predict(X_cv)
y_test_pred = logisticRegression.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
cv_accuracy = accuracy_score(y_cv, y_cv_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy = {train_accuracy}")
print(f"CV Accuracy = {cv_accuracy}")
print(f"Test Accuracy = {test_accuracy}")

# Cross validation using KFold
cv_scores = cross_val_score(logisticRegression, X_train, y_train, cv=10)
print(f"CV Scores = {cv_scores}")
print(f"Mean CV Score = {cv_scores.mean()}")
print(f"Std CV Score = {cv_scores.std()}")

classification_report_cv = classification_report(y_cv, y_cv_pred)
print(classification_report_cv)
# Out:
# Train Accuracy = 0.9500357142857143
# CV Accuracy = 0.9505
# Test Accuracy = 0.9456666666666667
# CV Scores = [0.94535714 0.94892857 0.95       0.94785714 0.94714286 0.95142857
#  0.94928571 0.94857143 0.9525     0.94857143]
# Mean CV Score = 0.9489642857142858
# Std CV Score = 0.0019394534260550515
#               precision    recall  f1-score   support
#
#          101       0.91      1.00      0.95      2672
#          120       1.00      0.99      1.00      1131
#          121       0.99      0.99      0.99       540
#          122       0.88      0.20      0.32       346
#          123       1.00      1.00      1.00       325
#          132       1.00      1.00      1.00       645
#          133       1.00      1.00      1.00       341
#
#     accuracy                           0.95      6000
#    macro avg       0.97      0.88      0.89      6000
# weighted avg       0.95      0.95      0.94      6000

# %% [markdown]
# ### SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier

sgdClassifier = SGDClassifier()
sgdClassifier.fit(X_train, y_train)
# Out:
# SGDClassifier()

# %%
# Get the metrics
y_train_pred = sgdClassifier.predict(X_train)
y_cv_pred = sgdClassifier.predict(X_cv)
y_test_pred = sgdClassifier.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
cv_accuracy = accuracy_score(y_cv, y_cv_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy = {train_accuracy}")
print(f"CV Accuracy = {cv_accuracy}")
print(f"Test Accuracy = {test_accuracy}")

# Cross validation using KFold
cv_scores = cross_val_score(sgdClassifier, X_train, y_train, cv=10)
print(f"CV Scores = {cv_scores}")
print(f"Mean CV Score = {cv_scores.mean()}")
print(f"Std CV Score = {cv_scores.std()}")

classification_report_cv = classification_report(y_cv, y_cv_pred, digits=4)
print(classification_report_cv)
# Out:
# Train Accuracy = 0.9029285714285714
# CV Accuracy = 0.903
# Test Accuracy = 0.8941666666666667
# CV Scores = [0.90107143 0.91892857 0.90392857 0.90785714 0.90607143 0.90642857
#  0.92142857 0.91035714 0.89714286 0.91178571]
# Mean CV Score = 0.9085000000000001
# Std CV Score = 0.007112076535939501
#               precision    recall  f1-score   support
#
#          101     0.8839    1.0000    0.9384      2672
#          120     0.9683    1.0000    0.9839      1131
#          121     0.9447    0.7593    0.8419       540
#          122     0.0000    0.0000    0.0000       346
#          123     0.9939    1.0000    0.9969       325
#          132     0.8538    0.8419    0.8478       645
#          133     0.8404    0.9883    0.9084       341
#
#     accuracy                         0.9030      6000
#    macro avg     0.7836    0.7985    0.7882      6000
# weighted avg     0.8546    0.9030    0.8759      6000

# %% [markdown]
# ### K-Neighbours Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knnClassifier = KNeighborsClassifier()
knnClassifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Get the metrics
y_train_pred = knnClassifier.predict(X_train)
y_cv_pred = knnClassifier.predict(X_cv)
y_test_pred = knnClassifier.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
cv_accuracy = accuracy_score(y_cv, y_cv_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy = {train_accuracy}")
print(f"CV Accuracy = {cv_accuracy}")
print(f"Test Accuracy = {test_accuracy}")

# Cross validation using KFold
cv_scores = cross_val_score(knnClassifier, X_train, y_train, cv=10)
print(f"CV Scores = {cv_scores}")
print(f"Mean CV Score = {cv_scores.mean()}")
print(f"Std CV Score = {cv_scores.std()}")

classification_report_cv = classification_report(y_cv, y_cv_pred)
print(classification_report_cv)
# Out:
# Train Accuracy = 0.9548214285714286
# CV Accuracy = 0.9243333333333333
# Test Accuracy = 0.9263333333333333
# CV Scores = [0.91857143 0.92178571 0.925      0.91785714 0.92321429 0.925
#  0.91821429 0.93178571 0.92821429 0.91607143]
# Mean CV Score = 0.9225714285714286
# Std CV Score = 0.004785714285714308
#               precision    recall  f1-score   support
#
#          101       0.95      0.95      0.95      2672
#          120       0.96      0.96      0.96      1131
#          121       0.93      0.92      0.92       540
#          122       0.65      0.70      0.67       346
#          123       1.00      1.00      1.00       325
#          132       0.86      0.95      0.91       645
#          133       0.90      0.70      0.79       341
#
#     accuracy                           0.92      6000
#    macro avg       0.89      0.88      0.89      6000
# weighted avg       0.93      0.92      0.92      6000

# %% [markdown]
# ### SVC Classifier

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Get the metrics
y_train_pred = svc.predict(X_train)
y_cv_pred = svc.predict(X_cv)
y_test_pred = svc.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
cv_accuracy = accuracy_score(y_cv, y_cv_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy = {train_accuracy}")
print(f"CV Accuracy = {cv_accuracy}")
print(f"Test Accuracy = {test_accuracy}")

# Cross validation using KFold
cv_scores = cross_val_score(svc, X_train, y_train, cv=10)
print(f"CV Scores = {cv_scores}")
print(f"Mean CV Score = {cv_scores.mean()}")
print(f"Std CV Score = {cv_scores.std()}")

classification_report_cv = classification_report(y_cv, y_cv_pred)
print(classification_report_cv)
# Out:
# Train Accuracy = 0.9673214285714286
# CV Accuracy = 0.9673333333333334
# Test Accuracy = 0.964
# CV Scores = [0.96035714 0.9675     0.96714286 0.96392857 0.96357143 0.9675
#  0.96428571 0.96642857 0.96357143 0.95964286]
# Mean CV Score = 0.964392857142857
# Std CV Score = 0.0026728510345811005
#               precision    recall  f1-score   support
#
#          101       0.94      1.00      0.97      2672
#          120       1.00      1.00      1.00      1131
#          121       0.99      1.00      0.99       540
#          122       0.93      0.50      0.65       346
#          123       1.00      1.00      1.00       325
#          132       1.00      1.00      1.00       645
#          133       1.00      0.99      1.00       341
#
#     accuracy                           0.97      6000
#    macro avg       0.98      0.93      0.94      6000
# weighted avg       0.97      0.97      0.96      6000

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

decisionTreeClassifier = DecisionTreeClassifier()
decisionTreeClassifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Get the metrics
y_train_pred = decisionTreeClassifier.predict(X_train)
y_cv_pred = decisionTreeClassifier.predict(X_cv)
y_test_pred = decisionTreeClassifier.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
cv_accuracy = accuracy_score(y_cv, y_cv_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy = {train_accuracy}")
print(f"CV Accuracy = {cv_accuracy}")
print(f"Test Accuracy = {test_accuracy}")

# Cross validation using KFold
cv_scores = cross_val_score(decisionTreeClassifier, X_train, y_train, cv=10)
print(f"CV Scores = {cv_scores}")
print(f"Mean CV Score = {cv_scores.mean()}")
print(f"Std CV Score = {cv_scores.std()}")

classification_report_cv = classification_report(y_cv, y_cv_pred)
print(classification_report_cv)
# Out:
# Train Accuracy = 1.0
# CV Accuracy = 0.9503333333333334
# Test Accuracy = 0.95
# CV Scores = [0.95107143 0.94892857 0.95107143 0.95392857 0.95178571 0.95428571
#  0.94892857 0.95892857 0.95678571 0.95214286]
# Mean CV Score = 0.9527857142857142
# Std CV Score = 0.0030714285714285687
#               precision    recall  f1-score   support
#
#          101       0.96      0.95      0.96      2672
#          120       0.98      0.98      0.98      1131
#          121       0.96      0.96      0.96       540
#          122       0.67      0.70      0.69       346
#          123       1.00      1.00      1.00       325
#          132       0.98      0.98      0.98       645
#          133       0.95      0.96      0.96       341
#
#     accuracy                           0.95      6000
#    macro avg       0.93      0.93      0.93      6000
# weighted avg       0.95      0.95      0.95      6000

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

randomForestClassifier = RandomForestClassifier()
randomForestClassifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Get the metrics
y_train_pred = randomForestClassifier.predict(X_train)
y_cv_pred = randomForestClassifier.predict(X_cv)
y_test_pred = randomForestClassifier.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
cv_accuracy = accuracy_score(y_cv, y_cv_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy = {train_accuracy}")
print(f"CV Accuracy = {cv_accuracy}")
print(f"Test Accuracy = {test_accuracy}")

# Cross validation using KFold
cv_scores = cross_val_score(randomForestClassifier, X_train, y_train, cv=10)
print(f"CV Scores = {cv_scores}")
print(f"Mean CV Score = {cv_scores.mean()}")
print(f"Std CV Score = {cv_scores.std()}")

classification_report_cv = classification_report(y_cv, y_cv_pred)
print(classification_report_cv)
# Out:
# Train Accuracy = 1.0
# CV Accuracy = 0.9678333333333333
# Test Accuracy = 0.9691666666666666
# CV Scores = [0.96892857 0.97178571 0.97607143 0.96714286 0.96857143 0.97214286
#  0.96964286 0.97214286 0.96964286 0.96464286]
# Mean CV Score = 0.9700714285714286
# Std CV Score = 0.0029914845130531386
#               precision    recall  f1-score   support
#
#          101       0.97      0.97      0.97      2672
#          120       0.99      1.00      0.99      1131
#          121       0.99      0.98      0.98       540
#          122       0.77      0.74      0.75       346
#          123       1.00      1.00      1.00       325
#          132       0.99      1.00      1.00       645
#          133       1.00      0.98      0.99       341
#
#     accuracy                           0.97      6000
#    macro avg       0.96      0.95      0.95      6000
# weighted avg       0.97      0.97      0.97      6000

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradientBoostingClassifier = GradientBoostingClassifier()
gradientBoostingClassifier.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
# Get the metrics
y_train_pred = gradientBoostingClassifier.predict(X_train)
y_cv_pred = gradientBoostingClassifier.predict(X_cv)
y_test_pred = gradientBoostingClassifier.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
cv_accuracy = accuracy_score(y_cv, y_cv_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy = {train_accuracy}")
print(f"CV Accuracy = {cv_accuracy}")
print(f"Test Accuracy = {test_accuracy}")

# Cross validation using KFold
cv_scores = cross_val_score(gradientBoostingClassifier, X_train, y_train, cv=10)
print(f"CV Scores = {cv_scores}")
print(f"Mean CV Score = {cv_scores.mean()}")
print(f"Std CV Score = {cv_scores.std()}")

classification_report_cv = classification_report(y_cv, y_cv_pred)
print(classification_report_cv)
# Out:
# Train Accuracy = 0.9796071428571429
# CV Accuracy = 0.9671666666666666
# Test Accuracy = 0.9655
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 15
#      12 print(f"Test Accuracy = {test_accuracy}")
#      14 # Cross validation using KFold
# ---> 15 cv_scores = cross_val_score(gradientBoostingClassifier, X_train, y_train, cv=10)
#      16 print(f"CV Scores = {cv_scores}")
#      17 print(f"Mean CV Score = {cv_scores.mean()}")
#
# File c:\Users\ojass\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:562, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     559 # To ensure multimetric format is not supported
#     560 scorer = check_scoring(estimator, scoring=scoring)
# --> 562 cv_results = cross_validate(
#     563     estimator=estimator,
# ...

# %% [markdown]
# We are discarding GradientBoostingClassifier since it was taking too much time to cross-validate using KFold cross=validation.

# %% [markdown]
# ### XGB Classifier

# %%
from xgboost import XGBClassifier

target_labels = {101:0, 120:1, 121:2, 122:3, 123:4, 132:5, 133:6}

y_train_encoded = np.array([target_labels[i] for i in y_train])
y_cv_encoded = np.array([target_labels[i] for i in y_cv])
y_test_encoded = np.array([target_labels[i] for i in y_test])

xgbClassifier = XGBClassifier()
xgbClassifier.fit(X_train, y_train_encoded)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# Get the metrics
y_train_pred = xgbClassifier.predict(X_train)
y_cv_pred = xgbClassifier.predict(X_cv)
y_test_pred = xgbClassifier.predict(X_test)

train_accuracy = accuracy_score(y_train_encoded, y_train_pred)
cv_accuracy = accuracy_score(y_cv_encoded, y_cv_pred)
test_accuracy = accuracy_score(y_test_encoded, y_test_pred)

print(f"Train Accuracy = {train_accuracy}")
print(f"CV Accuracy = {cv_accuracy}")
print(f"Test Accuracy = {test_accuracy}")

# Cross validation using KFold
cv_scores = cross_val_score(xgbClassifier, X_train, y_train_encoded, cv=10)
print(f"CV Scores = {cv_scores}")
print(f"Mean CV Score = {cv_scores.mean()}")
print(f"Std CV Score = {cv_scores.std()}")

classification_report_cv = classification_report(y_cv_encoded, y_cv_pred)
print(classification_report_cv)
# Out:
# Train Accuracy = 1.0
# CV Accuracy = 0.9751666666666666
# Test Accuracy = 0.9746666666666667
# CV Scores = [0.97857143 0.98107143 0.97928571 0.9725     0.975      0.98
#  0.97642857 0.97821429 0.97571429 0.97214286]
# Mean CV Score = 0.9768928571428572
# Std CV Score = 0.0029060545523483237
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      2672
#            1       0.99      1.00      1.00      1131
#            2       0.99      0.99      0.99       540
#            3       0.79      0.84      0.81       346
#            4       1.00      1.00      1.00       325
#            5       1.00      1.00      1.00       645
#            6       1.00      0.99      1.00       341
#
#     accuracy                           0.98      6000
#    macro avg       0.96      0.97      0.97      6000
# weighted avg       0.98      0.98      0.98      6000

# %% [markdown]
# Let us also test using neural networks.

# %%
# Create a classification neural network model to classify the supernovae into 7 different lcasses
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam

tf.random.set_seed(1008)

model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(10,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(7, activation='linear')
], name='SupernovaeClassifier')

model.compile(optimizer=Adam(learning_rate=0.001), loss=SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

model.summary()
# Out:
# Model: "SupernovaeClassifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                704
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 7)                 231
#
# ...
# Total params: 7175 (28.03 KB)
# Trainable params: 7175 (28.03 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train_encoded, epochs=200, batch_size=64, validation_data=(X_cv, y_cv_encoded))

# Plot the training and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 438/438 [==============================] - 3s 4ms/step - loss: 0.4626 - accuracy: 0.8424 - val_loss: 0.1161 - val_accuracy: 0.9590
# Epoch 2/200
# 438/438 [==============================] - 1s 3ms/step - loss: 0.0860 - accuracy: 0.9685 - val_loss: 0.0641 - val_accuracy: 0.9775
# Epoch 3/200
# 438/438 [==============================] - 1s 3ms/step - loss: 0.0575 - accuracy: 0.9783 - val_loss: 0.0585 - val_accuracy: 0.9773
# Epoch 4/200
# 438/438 [==============================] - 1s 3ms/step - loss: 0.0464 - accuracy: 0.9816 - val_loss: 0.0405 - val_accuracy: 0.9848
# Epoch 5/200
# 438/438 [==============================] - 1s 2ms/step - loss: 0.0363 - accuracy: 0.9876 - val_loss: 0.0356 - val_accuracy: 0.9848
# Epoch 6/200
# 438/438 [==============================] - 1s 3ms/step - loss: 0.0318 - accuracy: 0.9885 - val_loss: 0.0272 - val_accuracy: 0.9907
# Epoch 7/200
# ...

# %%
# Get the test accuracy
test_loss, test_accuracy = model.evaluate(X_test, y_test_encoded)
print(f"Test Accuracy = {test_accuracy}")
# Out:
# 188/188 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9942
# Test Accuracy = 0.9941666722297668

# %%
# Get the precision, recall and f1-score
y_cv_pred = model.predict(X_cv)
y_cv_pred = np.argmax(y_cv_pred, axis=1)

classification_report_test = classification_report(y_cv_encoded, y_cv_pred, digits=5)
print(classification_report_test)
# Out:
# 188/188 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0    0.99178   0.99401   0.99290      2672
#            1    1.00000   1.00000   1.00000      1131
#            2    1.00000   1.00000   1.00000       540
#            3    0.95294   0.93642   0.94461       346
#            4    1.00000   1.00000   1.00000       325
#            5    1.00000   0.99845   0.99922       645
#            6    0.99708   1.00000   0.99854       341
#
#     accuracy                        0.99350      6000
#    macro avg    0.99169   0.98984   0.99075      6000
# weighted avg    0.99346   0.99350   0.99348      6000

# %% [markdown]
# Now, instead of using the PCA reduced data, let us use all the features.

# %%
X_train_no_pca, X_, y_train_no_pca, y_ = train_test_split(X_minmax, y, test_size=0.3, random_state=42)
X_cv_no_pca, X_test_no_pca, y_cv_no_pca, y_test_no_pca = train_test_split(X_, y_, test_size=0.5, random_state=42)

# Encode y_train_no_pca, y_cv_no_pca and y_test_no_pca
y_train_no_pca_encoded = np.array([target_labels[i] for i in y_train_no_pca])
y_cv_no_pca_encoded = np.array([target_labels[i] for i in y_cv_no_pca])
y_test_no_pca_encoded = np.array([target_labels[i] for i in y_test_no_pca])

# %%
tf.random.set_seed(1008)

model_no_pca = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(7, activation='linear')
], name='SupernovaeClassifierNoPCA')

model_no_pca.compile(optimizer=Adam(learning_rate=0.001), loss=SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

model_no_pca.summary()
# Out:
# Model: "SupernovaeClassifierNoPCA"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 64)                3136
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 7)                 231
#
# ...
# Total params: 9607 (37.53 KB)
# Trainable params: 9607 (37.53 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_no_pca = model_no_pca.fit(X_train_no_pca, y_train_no_pca_encoded, epochs=30, batch_size=64, validation_data=(X_cv_no_pca, y_cv_no_pca_encoded))

# Plot the training and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history_no_pca.history['accuracy'], label='Train Accuracy')
plt.plot(history_no_pca.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/30
# 438/438 [==============================] - 2s 4ms/step - loss: 0.6104 - accuracy: 0.7859 - val_loss: 0.2139 - val_accuracy: 0.9205
# Epoch 2/30
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1383 - accuracy: 0.9501 - val_loss: 0.1001 - val_accuracy: 0.9610
# Epoch 3/30
# 438/438 [==============================] - 1s 3ms/step - loss: 0.0811 - accuracy: 0.9715 - val_loss: 0.0656 - val_accuracy: 0.9765
# Epoch 4/30
# 438/438 [==============================] - 1s 2ms/step - loss: 0.0672 - accuracy: 0.9743 - val_loss: 0.0465 - val_accuracy: 0.9878
# Epoch 5/30
# 438/438 [==============================] - 1s 3ms/step - loss: 0.0476 - accuracy: 0.9835 - val_loss: 0.0372 - val_accuracy: 0.9890
# Epoch 6/30
# 438/438 [==============================] - 1s 3ms/step - loss: 0.0409 - accuracy: 0.9859 - val_loss: 0.0321 - val_accuracy: 0.9927
# Epoch 7/30
# ...

# %%
# Get the test accuracy
test_loss, test_accuracy = model_no_pca.evaluate(X_test_no_pca, y_test_no_pca_encoded)
print(f"Test Accuracy = {test_accuracy}")
# Out:
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0046 - accuracy: 0.9985
# Test Accuracy = 0.9984999895095825

# %%
# Get the precision, recall and f1-score
y_cv_pred = model_no_pca.predict(X_cv_no_pca)
y_cv_pred = np.argmax(y_cv_pred, axis=1)

classification_report_test = classification_report(y_cv_no_pca_encoded, y_cv_pred, digits=5)
print(classification_report_test)
# Out:
# 188/188 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0    0.99962   0.99626   0.99794      2672
#            1    1.00000   1.00000   1.00000      1131
#            2    1.00000   1.00000   1.00000       540
#            3    0.97183   0.99711   0.98431       346
#            4    1.00000   1.00000   1.00000       325
#            5    1.00000   1.00000   1.00000       645
#            6    1.00000   1.00000   1.00000       341
#
#     accuracy                        0.99817      6000
#    macro avg    0.99592   0.99905   0.99746      6000
# weighted avg    0.99821   0.99817   0.99818      6000

# %% [markdown]
# The models with pca data and with no pca data given approximately the same output. However, the model with no pca data gives the overall better output.

# %%
best_model = model_no_pca

# %%
# Get the confusion matrix and ROC curve
from sklearn.metrics import confusion_matrix, roc_curve, auc

# Get the confusion matrix
y_test_pred = best_model.predict(X_test_no_pca)
y_test_pred = np.argmax(y_test_pred, axis=1)

conf_matrix = confusion_matrix(y_test_no_pca_encoded, y_test_pred)

# Plot the confusion matrix
plt.figure(figsize=(12, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis', linewidths=0.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 188/188 [==============================] - 1s 2ms/step

# %%
# Get the ROC curve
y_test_pred = best_model.predict(X_test_no_pca)

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_test_no_pca_encoded, y_test_pred[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curve
plt.figure(figsize=(12, 6))
for i in range(7):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
# Out:
# ...
# 188/188 [==============================] - 1s 3ms/step
